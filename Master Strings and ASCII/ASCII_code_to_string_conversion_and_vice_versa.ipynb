# %%
text = 'The quick brown fox jumps over the lazy dog'

# %%
for txt in text:
  print(ord(txt))
# Out:
# 84
# 104
# 101
# 32
# 113
# 117
# 105
# 99
# 107
# 32
# 98
# 114
# 111
# 119
# 110
# 32
# 102
# 111
# 120
# 32
# 106
# 117
# 109
# 112
# 115
# 32
# 111
# 118
# 101
# 114
# 32
# 116
# 104
# 101
# 32
# 108
# 97
# 122
# 121
# 32
# 100
# 111
# 103

# %% [markdown]
# ## **String to ASCII conversion** ![english-alphabet-stitched-thread-english-alphabet-stitched-thread-isolated-white-background-102122647.webp](data:image/webp;base64,...)

# %%
[ord(char) for char in text]
# Out:
# [84,
#  104,
#  101,
#  32,
#  113,
#  117,
#  105,
#  99,
#  107,
#  32,
#  98,
#  114,
#  111,
#  119,
#  110,
#  32,
#  102,
#  111,
#  120,
#  32,
#  106,
#  117,
#  109,
#  112,
#  115,
#  32,
#  111,
#  118,
#  101,
#  114,
#  32,
#  116,
#  104,
#  101,
#  32,
#  108,
#  97,
#  122,
#  121,
#  32,
#  100,
#  111,
#  103]

# %%
[{char:ord(char)} for char in text]
# Out:
# [{'T': 84},
#  {'h': 104},
#  {'e': 101},
#  {' ': 32},
#  {'q': 113},
#  {'u': 117},
#  {'i': 105},
#  {'c': 99},
#  {'k': 107},
#  {' ': 32},
#  {'b': 98},
#  {'r': 114},
#  {'o': 111},
#  {'w': 119},
#  {'n': 110},
#  {' ': 32},
#  {'f': 102},
#  {'o': 111},
#  {'x': 120},
#  {' ': 32},
#  {'j': 106},
#  {'u': 117},
#  {'m': 109},
#  {'p': 112},
#  {'s': 115},
#  {' ': 32},
#  {'o': 111},
#  {'v': 118},
#  {'e': 101},
#  {'r': 114},
#  {' ': 32},
#  {'t': 116},
#  {'h': 104},
#  {'e': 101},
#  {' ': 32},
#  {'l': 108},
#  {'a': 97},
#  {'z': 122},
#  {'y': 121},
#  {' ': 32},
#  {'d': 100},
#  {'o': 111},
#  {'g': 103}]

# %% [markdown]
# ## **2. ASCII to string conversion**![convert-ascii-to-string.png](data:image/png;base64,...)

# %%
ascii_ = [{char:ord(char)} for char in text]
ascii_
# Out:
# [{'T': 84},
#  {'h': 104},
#  {'e': 101},
#  {' ': 32},
#  {'q': 113},
#  {'u': 117},
#  {'i': 105},
#  {'c': 99},
#  {'k': 107},
#  {' ': 32},
#  {'b': 98},
#  {'r': 114},
#  {'o': 111},
#  {'w': 119},
#  {'n': 110},
#  {' ': 32},
#  {'f': 102},
#  {'o': 111},
#  {'x': 120},
#  {' ': 32},
#  {'j': 106},
#  {'u': 117},
#  {'m': 109},
#  {'p': 112},
#  {'s': 115},
#  {' ': 32},
#  {'o': 111},
#  {'v': 118},
#  {'e': 101},
#  {'r': 114},
#  {' ': 32},
#  {'t': 116},
#  {'h': 104},
#  {'e': 101},
#  {' ': 32},
#  {'l': 108},
#  {'a': 97},
#  {'z': 122},
#  {'y': 121},
#  {' ': 32},
#  {'d': 100},
#  {'o': 111},
#  {'g': 103}]

# %%
ascii_ = [ord(char) for char in text]
ascii_
# Out:
# [84,
#  104,
#  101,
#  32,
#  113,
#  117,
#  105,
#  99,
#  107,
#  32,
#  98,
#  114,
#  111,
#  119,
#  110,
#  32,
#  102,
#  111,
#  120,
#  32,
#  106,
#  117,
#  109,
#  112,
#  115,
#  32,
#  111,
#  118,
#  101,
#  114,
#  32,
#  116,
#  104,
#  101,
#  32,
#  108,
#  97,
#  122,
#  121,
#  32,
#  100,
#  111,
#  103]

# %%
ord('A')
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(33)
# Out:
# '!'

# %%
# reverse the text
'The quick brown fox jumps over the lazy dog'[::-1]
# Out:
# 'god yzal eht revo spmuj xof nworb kciuq ehT'

# %%
'god yzal eht revo spmuj xof nworb kciuq ehT'[::-1]
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
''.join([chr(acs) for acs in ascii_ ])
# Out:
# 'The quick brown fox jumps over the lazy dog'
