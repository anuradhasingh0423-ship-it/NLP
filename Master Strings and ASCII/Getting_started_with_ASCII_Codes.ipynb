# %%
'A'
# Out:
# 'A'

# %%
print('A')
# Out:
# A

# %%
ord('A')
# Out:
# 65

# %%
ord("A")
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('h')
# Out:
# 104

# %%
ord('}')
# Out:
# 125

# %%
ord('{')
# Out:
# 123

# %%
ord('1')
# Out:
# 49

# %%
ord('!')
# Out:
# 33

# %%
ord( ' ')
# Out:
# 32

# %%
ord('R')
# Out:
# 82

# %%
name = 'Anuradha Singh'

# %%
for char in name:
  print(ord(char))
# Out:
# 65
# 110
# 117
# 114
# 97
# 100
# 104
# 97
# 32
# 83
# 105
# 110
# 103
# 104

# %%
[ord(char) for char in name]
# Out:
# [65, 110, 117, 114, 97, 100, 104, 97, 32, 83, 105, 110, 103, 104]

# %%
print([char for char in name])
print([ord(char) for char in name])
# Out:
# ['A', 'n', 'u', 'r', 'a', 'd', 'h', 'a', ' ', 'S', 'i', 'n', 'g', 'h']
# [65, 110, 117, 114, 97, 100, 104, 97, 32, 83, 105, 110, 103, 104]

# %%
name = 'Monkey Man'

# %%
for i in name:
  print(ord(i))
# Out:
# 77
# 111
# 110
# 107
# 101
# 121
# 32
# 77
# 97
# 110

# %%
print([char for char in name])
print([ord(char) for char in name])
# Out:
# ['M', 'o', 'n', 'k', 'e', 'y', ' ', 'M', 'a', 'n']
# [77, 111, 110, 107, 101, 121, 32, 77, 97, 110]
