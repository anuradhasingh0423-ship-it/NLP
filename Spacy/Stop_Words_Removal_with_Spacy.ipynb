# %% [markdown]
# ## Stop Words
# A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine has been programmed to ignore, both when indexing entries for searching and when retrieving them as the result of a search query.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
txt = ''' Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical
          algorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.[1] Within a
          subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms,
          to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing,
          computer vision, speech recognition, email filtering, agriculture,and medicine. The application of ML to business problems is known as predictive analytics.
          Statistics and mathematical optimisation (mathematical programming) methods compose the foundations of machine learning. Data mining is a related
          field of study, focusing on exploratory data analysis (EDA) through unsupervised learning '''

# %%
nlp

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'top', 'i', "'ve", 'after', 'four', 'n’t', 'via', 'for', 'own', 'mostly', 'however', 'eight', 'full', 'my', 'behind', 'on', 'while', 'thereafter', 'well', 'its', 'either', 'thereupon', 'next', 'seeming', 'yourself', 'say', 'should', 'sometimes', 'or', 'see', 'thereby', 'could', 'did', 'thus', 'nor', 'yet', 'both', 'fifty', 'much', 'himself', 'seems', 'unless', 'used', 'keep', 'whither', "'ll", 'six', 'otherwise', 'with', '‘m', 'never', 'anywhere', 'becomes', 'further', 'most', 'since', 'am', 'call', 'few', '’m', 'very', 'although', 'serious', 'without', 'anyway', 'he', '‘s', 'side', 'they', 'itself', 'why', 'whereas', 'beside', 'several', 'amongst', 'beyond', 'each', 'bottom', 'yourselves', 'his', 'doing', 'every', 'by', 'this', 'neither', 'sixty', 'along', 'ever', 'and', 'whereafter', 'above', 'ten', 'whether', 'until', 'really', 'might', 'only', 'because', 'their', 'as', 'into', 'whose', 'which', 'whence', 'there', 'when', 'rather', 'less', 'to', 'nowhere', 'all', 'those', 'whole'
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['the'].is_stop
# Out:
# True

# %%
nlp.vocab['The'].is_stop
# Out:
# True

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %% [markdown]
# #### Adding custom words into the list of StopWords

# %%
nlp.Defaults.stop_words.add('hello')

# %%
nlp.vocab['hello'].is_stop
# Out:
# True

# %% [markdown]
# #### Removing custom words from StopWords

# %%
nlp.Defaults.stop_words.remove('the')
# Out:
# True

# %%
nlp.vocab['the'].is_stop = False

# %%
nlp.vocab['the'].is_stop
# Out:
# False

# %% [markdown]
# #### Removing StopWords from Corpus

# %%
txt = ''' Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical
          algorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.[1] Within a
          subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms,
          to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing,
          computer vision, speech recognition, email filtering, agriculture,and medicine. The application of ML to business problems is known as predictive analytics.
          Statistics and mathematical optimisation (mathematical programming) methods compose the foundations of machine learning. Data mining is a related
          field of study, focusing on exploratory data analysis (EDA) through unsupervised learning '''

# %%
txt
# Out:
# ' Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical\n          algorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.[1] Within a \n          subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms,\n          to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing, \n          computer vision, speech recognition, email filtering, agriculture,and medicine. The application of ML to business problems is known as predictive analytics.\n          Statistics and mathematical optimisation (mathematical programming) methods compose the foundations of machine learning. Data mining is a related\n          field of study, focusing on exploratory data analysis (EDA) through unsupervised lea
# ...

# %%
txt = txt.replace('\n', '')
txt = txt.replace('  ','')
txt = txt.strip()
txt
# Out:
# 'Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statisticalalgorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.[1] Within a subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms,to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing, computer vision, speech recognition, email filtering, agriculture,and medicine. The application of ML to business problems is known as predictive analytics.Statistics and mathematical optimisation (mathematical programming) methods compose the foundations of machine learning. Data mining is a relatedfield of study, focusing on exploratory data analysis (EDA) through unsupervised learning'

# %%
corp = nlp(txt)

# %%
corp
# Out:
# Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statisticalalgorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.[1] Within a subdiscipline in machine learning, advances in the field of deep learning have allowed neural networks, a class of statistical algorithms,to surpass many previous machine learning approaches in performance.ML finds application in many fields, including natural language processing, computer vision, speech recognition, email filtering, agriculture,and medicine. The application of ML to business problems is known as predictive analytics.Statistics and mathematical optimisation (mathematical programming) methods compose the foundations of machine learning. Data mining is a relatedfield of study, focusing on exploratory data analysis (EDA) through unsupervised learning

# %%
for token in corp:
  print(token)
# Out:
# Machine
# learning
# (
# ML
# )
# is
# a
# field
# of
# study
# in
# artificial
# intelligence
# concerned
# with
# the
# development
# and
# study
# of
# statisticalalgorithms
# that
# can
# learn
# from
# data
# and
# generalize
# to
# unseen
# data
# ,
# and
# thus
# perform
# tasks
# without
# explicit
# instructions.[1
# ]
# Within
# a
# subdiscipline
# in
# machine
# learning
# ,
# advances
# in
# the
# field
# of
# deep
# learning
# have
# allowed
# neural
# networks
# ,
# a
# class
# of
# statistical
# algorithms
# ,
# to
# surpass
# many
# previous
# machine
# learning
# approaches
# in
# performance
# .
# ML
# finds
# application
# in
# many
# fields
# ,
# including
# natural
# language
# processing
# ,
# computer
# vision
# ,
# speech
# recognition
# ,
# email
# filtering
# ,
# agriculture
# ,
# and
# medicine
# .
# The
# application
# of
# ML
# to
# business
# problems
# is
# known
# as
# predictive
# analytics
# .
# Statistics
# and
# mathematical
# optimisation
# (
# ...

# %% [markdown]
# #### Finding StopWords from the corpus

# %%
stop_word = []
for token in corp:
  if token.is_stop:
    stop_word.append(token)

print(stop_word)
# Out:
# [is, a, of, in, with, and, of, that, can, from, and, to, and, thus, without, Within, a, in, in, of, have, a, of, to, many, in, in, many, and, The, of, to, is, as, and, of, is, a, of, on, through]

# %%
len(stop_word)
# Out:
# 41

# %%
len(set(stop_word))
# Out:
# 41

# %%
stop_word = set( )
for token in corp:
  if token.is_stop:
    stop_word.add(token.text)

print(stop_word)
print(len(stop_word))
# Out:
# {'with', 'in', 'as', 'Within', 'through', 'that', 'of', 'thus', 'a', 'and', 'without', 'to', 'is', 'can', 'The', 'have', 'from', 'many', 'on'}
# 19

# %% [markdown]
# #### Find the words that doesn't belong to stop_words

# %%
for token in corp:
  if token.is_stop:
    print(token)
# Out:
# is
# a
# of
# in
# with
# and
# of
# that
# can
# from
# and
# to
# and
# thus
# without
# Within
# a
# in
# in
# of
# have
# a
# of
# to
# many
# in
# in
# many
# and
# The
# of
# to
# is
# as
# and
# of
# is
# a
# of
# on
# through

# %%
for token in corp:
  if not token.is_stop:
    print(token)
# Out:
# Machine
# learning
# (
# ML
# )
# field
# study
# artificial
# intelligence
# concerned
# the
# development
# study
# statisticalalgorithms
# learn
# data
# generalize
# unseen
# data
# ,
# perform
# tasks
# explicit
# instructions.[1
# ]
# subdiscipline
# machine
# learning
# ,
# advances
# the
# field
# deep
# learning
# allowed
# neural
# networks
# ,
# class
# statistical
# algorithms
# ,
# surpass
# previous
# machine
# learning
# approaches
# performance
# .
# ML
# finds
# application
# fields
# ,
# including
# natural
# language
# processing
# ,
# computer
# vision
# ,
# speech
# recognition
# ,
# email
# filtering
# ,
# agriculture
# ,
# medicine
# .
# application
# ML
# business
# problems
# known
# predictive
# analytics
# .
# Statistics
# mathematical
# optimisation
# (
# mathematical
# programming
# )
# methods
# compose
# the
# foundations
# machine
# learning
# .
# Data
# mining
# relatedfield
# study
# ,
# focusing
# exploratory
# data
# analysis
# (
# EDA
# )
# ...

# %%
' '.join([token.text for token in corp if not token.is_stop])
# Out:
# 'Machinelearning(ML)fieldstudyartificialintelligenceconcernedthedevelopmentstudystatisticalalgorithmslearndatageneralizeunseendata,performtasksexplicitinstructions.[1]subdisciplinemachinelearning,advancesthefielddeeplearningallowedneuralnetworks,classstatisticalalgorithms,surpasspreviousmachinelearningapproachesperformance.MLfindsapplicationfields,includingnaturallanguageprocessing,computervision,speechrecognition,emailfiltering,agriculture,medicine.applicationMLbusinessproblemsknownpredictiveanalytics.Statisticsmathematicaloptimisation(mathematicalprogramming)methodscomposethefoundationsmachinelearning.Dataminingrelatedfieldstudy,focusingexploratorydataanalysis(EDA)unsupervisedlearning'
